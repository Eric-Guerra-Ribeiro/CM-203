# %% [markdown]
# **Instituto Tecnológico de Aeronáutica – ITA**
#
# **Visão Computacional - CM-203**
#
# **Professores:**
#
# Elcio Hideiti Shiguemori
#
# Gabriel Adriano de Melo
#
# Marcos Ricardo Omena de Albuquerque Maximo
#
# **Orientações padrão:**
#
# Antes de você entregar o Lab, tenha certeza de que tudo está rodando corretamente (sequencialmente): Primeiro, **reinicie o kernel** (`Runtime->Restart Runtime` no Colab ou `Kernel->Restart` no Jupyter), depois rode todas as células (`Runtime->Run All` no Colab ou `Cell->Run All` no Jupyter) e verifique que as células rodem sem erros, principalmente as de correção automática que apresentem os `assert`s.
#
# É muito importante que vocês não apaguem as células de resposta para preenchimento, isto é, as que contenham o `ESCREVA SEU CÓDIGO AQUI` ou o "ESCREVA SUA RESPOSTA AQUI", além das células dos `assert`, pois elas contém metadados com o id da célula para os sistemas de correção automatizada e manual. O sistema de correção automatizada executa todo o código do notebook, adicionando testes extras nas células de teste. Não tem problema vocês criarem mais células, mas não apaguem as células de correção. Mantenham a solução dentro do espaço determinado, por organização. Se por acidente acontecer de apagarem alguma célula que deveria ter a resposta, recomendo iniciar de outro notebook (ou dar um `Undo` se possível), pois não adianta recriar a célula porque perdeu o ID.
#
# Os Notebooks foram programados para serem compatíveis com o Google Colab, instalando as dependências necessárias automaticamente a baixando os datasets necessários a cada Lab. Os comandos que se inicial por ! (ponto de exclamação) são de bash e também podem ser executados no terminal linux, que justamente instalam as dependências.

# %% [markdown]
# ---

# %% [markdown]
# # Laboratório de Odometria
#
# Neste laboratório iremos aplicar os nossos conhecimentos anteriores de visão estéreo, perpectiva de n pontos e de RANSAC em um problema de odometria.

# %%
# Se for executar localmente, tenha as seguintes bibliotecas instaladas
# !pip3 install opencv-contrib-python==4.6.0.66 Pillow==7.1.2 matplotlib==3.2.2 scipy==1.7.3 gdown==4.4.0

import cv2
import numpy as np
import PIL.Image
from matplotlib import pyplot as plt
from glob import glob
from pathlib import Path
from scipy.spatial.transform import Rotation as R

plt.style.use('seaborn-darkgrid')

# %% [markdown]
# Se for executar local e quiser alterar o Path, pode alterar aqui sem problemas para a correção automática.

# %%
! [ ! -d "./content/odometria" ] && gdown -O ./content/odometria.zip 1JanfRR4dJk6tfhpm_hTNRBkkNzoy7gpL && unzip ./content/odometria.zip -d ./content && rm ./content/odometria.zip
root_path = Path("./content/odometria")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JanfRR4dJk6tfhpm_hTNRBkkNzoy7gpL
# To: /home/eric/ITA/1Comp2Sem/CM-203/Lab4/content/odometria.zip
# 100%|████████████████████████████████████████| 367M/367M [01:20<00:00, 4.57MB/s]
# Archive:  ./content/odometria.zip
#    creating: ./content/odometria/
#    creating: ./content/odometria/esquerda/
#   inflating: ./content/odometria/esquerda/000000.png
#   inflating: ./content/odometria/esquerda/000001.png
#   inflating: ./content/odometria/esquerda/000002.png
#   inflating: ./content/odometria/esquerda/000003.png
#   inflating: ./content/odometria/esquerda/000004.png
#   inflating: ./content/odometria/esquerda/000005.png
#   inflating: ./content/odometria/esquerda/000006.png
#   inflating: ./content/odometria/esquerda/000007.png
#   inflating: ./content/odometria/esquerda/000008.png
#   inflating: ./content/odometria/esquerda/000009.png
#   inflating: ./content/odometria/esquerda/000010.png
#   inflating: ./content/odometria/esquerda/000011.png
#   inflating: ./content/odometria/esquerda/000012.png
#   inflating: ./content/odometria/esquerda/000013.png
#   inflating: ./content/odometria/esquerda/000014.png
#   inflating: ./content/odometria/esquerda/000015.png
#   inflating: ./content/odometria/esquerda/000016.png
#   inflating: ./content/odometria/esquerda/000017.png
#   inflating: ./content/odometria/esquerda/000018.png
#   inflating: ./content/odometria/esquerda/000019.png
#   inflating: ./content/odometria/esquerda/000020.png
#   inflating: ./content/odometria/esquerda/000021.png
#   inflating: ./content/odometria/esquerda/000022.png
#   inflating: ./content/odometria/esquerda/000023.png
#   inflating: ./content/odometria/esquerda/000024.png
#   inflating: ./content/odometria/esquerda/000025.png
#   inflating: ./content/odometria/esquerda/000026.png
#   inflating: ./content/odometria/esquerda/000027.png
#   inflating: ./content/odometria/esquerda/000028.png
#   inflating: ./content/odometria/esquerda/000029.png
#   inflating: ./content/odometria/esquerda/000030.png
#   inflating: ./content/odometria/esquerda/000031.png
#   inflating: ./content/odometria/esquerda/000032.png
#   inflating: ./content/odometria/esquerda/000033.png
#   inflating: ./content/odometria/esquerda/000034.png
#   inflating: ./content/odometria/esquerda/000035.png
#   inflating: ./content/odometria/esquerda/000036.png
#   inflating: ./content/odometria/esquerda/000037.png
#   inflating: ./content/odometria/esquerda/000038.png
#   inflating: ./content/odometria/esquerda/000039.png
#   inflating: ./content/odometria/esquerda/000040.png
#   inflating: ./content/odometria/esquerda/000041.png
#   inflating: ./content/odometria/esquerda/000042.png
#   inflating: ./content/odometria/esquerda/000043.png
#   inflating: ./content/odometria/esquerda/000044.png
#   inflating: ./content/odometria/esquerda/000045.png
#   inflating: ./content/odometria/esquerda/000046.png
#   inflating: ./content/odometria/esquerda/000047.png
#   inflating: ./content/odometria/esquerda/000048.png
#   inflating: ./content/odometria/esquerda/000049.png
#   inflating: ./content/odometria/esquerda/000050.png
#   inflating: ./content/odometria/esquerda/000051.png
#   inflating: ./content/odometria/esquerda/000052.png
#   inflating: ./content/odometria/esquerda/000053.png
#   inflating: ./content/odometria/esquerda/000054.png
#   inflating: ./content/odometria/esquerda/000055.png
#   inflating: ./content/odometria/esquerda/000056.png
#   inflating: ./content/odometria/esquerda/000057.png
#   inflating: ./content/odometria/esquerda/000058.png
#   inflating: ./content/odometria/esquerda/000059.png
#   inflating: ./content/odometria/esquerda/000060.png
#   inflating: ./content/odometria/esquerda/000061.png
#   inflating: ./content/odometria/esquerda/000062.png
#   inflating: ./content/odometria/esquerda/000063.png
#   inflating: ./content/odometria/esquerda/000064.png
#   inflating: ./content/odometria/esquerda/000065.png
#   inflating: ./content/odometria/esquerda/000066.png
#   inflating: ./content/odometria/esquerda/000067.png
#   inflating: ./content/odometria/esquerda/000068.png
#   inflating: ./content/odometria/esquerda/000069.png
#   inflating: ./content/odometria/esquerda/000070.png
#   inflating: ./content/odometria/esquerda/000071.png
#   inflating: ./content/odometria/esquerda/000072.png
#   inflating: ./content/odometria/esquerda/000073.png
#   inflating: ./content/odometria/esquerda/000074.png
#   inflating: ./content/odometria/esquerda/000075.png
#   inflating: ./content/odometria/esquerda/000076.png
#   inflating: ./content/odometria/esquerda/000077.png
#   inflating: ./content/odometria/esquerda/000078.png
#   inflating: ./content/odometria/esquerda/000079.png
#   inflating: ./content/odometria/esquerda/000080.png
#   inflating: ./content/odometria/esquerda/000081.png
#   inflating: ./content/odometria/esquerda/000082.png
#   inflating: ./content/odometria/esquerda/000083.png
#   inflating: ./content/odometria/esquerda/000084.png
#   inflating: ./content/odometria/esquerda/000085.png
#   inflating: ./content/odometria/esquerda/000086.png
#   inflating: ./content/odometria/esquerda/000087.png
#   inflating: ./content/odometria/esquerda/000088.png
#   inflating: ./content/odometria/esquerda/000089.png
#   inflating: ./content/odometria/esquerda/000090.png
#   inflating: ./content/odometria/esquerda/000091.png
#   inflating: ./content/odometria/esquerda/000092.png
#   inflating: ./content/odometria/esquerda/000093.png
#   inflating: ./content/odometria/esquerda/000094.png
#   inflating: ./content/odometria/esquerda/000095.png
#   inflating: ./content/odometria/esquerda/000096.png
#   inflating: ./content/odometria/esquerda/000097.png
#   inflating: ./content/odometria/esquerda/000098.png
#   inflating: ./content/odometria/esquerda/000099.png
#   inflating: ./content/odometria/esquerda/000100.png
#   inflating: ./content/odometria/esquerda/000101.png
#   inflating: ./content/odometria/esquerda/000102.png
#   inflating: ./content/odometria/esquerda/000103.png
#   inflating: ./content/odometria/esquerda/000104.png
#   inflating: ./content/odometria/esquerda/000105.png
#   inflating: ./content/odometria/esquerda/000106.png
#   inflating: ./content/odometria/esquerda/000107.png
#   inflating: ./content/odometria/esquerda/000108.png
#   inflating: ./content/odometria/esquerda/000109.png
#   inflating: ./content/odometria/esquerda/000110.png
#   inflating: ./content/odometria/esquerda/000111.png
#   inflating: ./content/odometria/esquerda/000112.png
#   inflating: ./content/odometria/esquerda/000113.png
#   inflating: ./content/odometria/esquerda/000114.png
#   inflating: ./content/odometria/esquerda/000115.png
#   inflating: ./content/odometria/esquerda/000116.png
#   inflating: ./content/odometria/esquerda/000117.png
#   inflating: ./content/odometria/esquerda/000118.png
#   inflating: ./content/odometria/esquerda/000119.png
#   inflating: ./content/odometria/esquerda/000120.png
#   inflating: ./content/odometria/esquerda/000121.png
#   inflating: ./content/odometria/esquerda/000122.png
#   inflating: ./content/odometria/esquerda/000123.png
#   inflating: ./content/odometria/esquerda/000124.png
#   inflating: ./content/odometria/esquerda/000125.png
#   inflating: ./content/odometria/esquerda/000126.png
#   inflating: ./content/odometria/esquerda/000127.png
#   inflating: ./content/odometria/esquerda/000128.png
#   inflating: ./content/odometria/esquerda/000129.png
#   inflating: ./content/odometria/esquerda/000130.png
#   inflating: ./content/odometria/esquerda/000131.png
#   inflating: ./content/odometria/esquerda/000132.png
#   inflating: ./content/odometria/esquerda/000133.png
#   inflating: ./content/odometria/esquerda/000134.png
#   inflating: ./content/odometria/esquerda/000135.png
#   inflating: ./content/odometria/esquerda/000136.png
#   inflating: ./content/odometria/esquerda/000137.png
#   inflating: ./content/odometria/esquerda/000138.png
#   inflating: ./content/odometria/esquerda/000139.png
#   inflating: ./content/odometria/esquerda/000140.png
#   inflating: ./content/odometria/esquerda/000141.png
#   inflating: ./content/odometria/esquerda/000142.png
#   inflating: ./content/odometria/esquerda/000143.png
#   inflating: ./content/odometria/esquerda/000144.png
#   inflating: ./content/odometria/esquerda/000145.png
#   inflating: ./content/odometria/esquerda/000146.png
#   inflating: ./content/odometria/esquerda/000147.png
#   inflating: ./content/odometria/esquerda/000148.png
#   inflating: ./content/odometria/esquerda/000149.png
#   inflating: ./content/odometria/esquerda/000150.png
#   inflating: ./content/odometria/esquerda/000151.png
#   inflating: ./content/odometria/esquerda/000152.png
#   inflating: ./content/odometria/esquerda/000153.png
#   inflating: ./content/odometria/esquerda/000154.png
#   inflating: ./content/odometria/esquerda/000155.png
#   inflating: ./content/odometria/esquerda/000156.png
#   inflating: ./content/odometria/esquerda/000157.png
#   inflating: ./content/odometria/esquerda/000158.png
#   inflating: ./content/odometria/esquerda/000159.png
#   inflating: ./content/odometria/esquerda/000160.png
#   inflating: ./content/odometria/esquerda/000161.png
#   inflating: ./content/odometria/esquerda/000162.png
#   inflating: ./content/odometria/esquerda/000163.png
#   inflating: ./content/odometria/esquerda/000164.png
#   inflating: ./content/odometria/esquerda/000165.png
#   inflating: ./content/odometria/esquerda/000166.png
#   inflating: ./content/odometria/esquerda/000167.png
#   inflating: ./content/odometria/esquerda/000168.png
#   inflating: ./content/odometria/esquerda/000169.png
#   inflating: ./content/odometria/esquerda/000170.png
#   inflating: ./content/odometria/esquerda/000171.png
#   inflating: ./content/odometria/esquerda/000172.png
#   inflating: ./content/odometria/esquerda/000173.png
#   inflating: ./content/odometria/esquerda/000174.png
#   inflating: ./content/odometria/esquerda/000175.png
#   inflating: ./content/odometria/esquerda/000176.png
#   inflating: ./content/odometria/esquerda/000177.png
#   inflating: ./content/odometria/esquerda/000178.png
#   inflating: ./content/odometria/esquerda/000179.png
#   inflating: ./content/odometria/esquerda/000180.png
#   inflating: ./content/odometria/esquerda/000181.png
#   inflating: ./content/odometria/esquerda/000182.png
#   inflating: ./content/odometria/esquerda/000183.png
#   inflating: ./content/odometria/esquerda/000184.png
#   inflating: ./content/odometria/esquerda/000185.png
#   inflating: ./content/odometria/esquerda/000186.png
#   inflating: ./content/odometria/esquerda/000187.png
#   inflating: ./content/odometria/esquerda/000188.png
#   inflating: ./content/odometria/esquerda/000189.png
#   inflating: ./content/odometria/esquerda/000190.png
#   inflating: ./content/odometria/esquerda/000191.png
#   inflating: ./content/odometria/esquerda/000192.png
#   inflating: ./content/odometria/esquerda/000193.png
#   inflating: ./content/odometria/esquerda/000194.png
#   inflating: ./content/odometria/esquerda/000195.png
#   inflating: ./content/odometria/esquerda/000196.png
#   inflating: ./content/odometria/esquerda/000197.png
#   inflating: ./content/odometria/esquerda/000198.png
#   inflating: ./content/odometria/esquerda/000199.png
#   inflating: ./content/odometria/esquerda/000200.png
#   inflating: ./content/odometria/esquerda/000201.png
#   inflating: ./content/odometria/esquerda/000202.png
#   inflating: ./content/odometria/esquerda/000203.png
#   inflating: ./content/odometria/esquerda/000204.png
#   inflating: ./content/odometria/esquerda/000205.png
#   inflating: ./content/odometria/esquerda/000206.png
#   inflating: ./content/odometria/esquerda/000207.png
#   inflating: ./content/odometria/esquerda/000208.png
#   inflating: ./content/odometria/esquerda/000209.png
#   inflating: ./content/odometria/esquerda/000210.png
#   inflating: ./content/odometria/esquerda/000211.png
#   inflating: ./content/odometria/esquerda/000212.png
#   inflating: ./content/odometria/esquerda/000213.png
#   inflating: ./content/odometria/esquerda/000214.png
#   inflating: ./content/odometria/esquerda/000215.png
#   inflating: ./content/odometria/esquerda/000216.png
#   inflating: ./content/odometria/esquerda/000217.png
#   inflating: ./content/odometria/esquerda/000218.png
#   inflating: ./content/odometria/esquerda/000219.png
#   inflating: ./content/odometria/esquerda/000220.png
#   inflating: ./content/odometria/esquerda/000221.png
#   inflating: ./content/odometria/esquerda/000222.png
#   inflating: ./content/odometria/esquerda/000223.png
#   inflating: ./content/odometria/esquerda/000224.png
#   inflating: ./content/odometria/esquerda/000225.png
#   inflating: ./content/odometria/esquerda/000226.png
#   inflating: ./content/odometria/esquerda/000227.png
#   inflating: ./content/odometria/esquerda/000228.png
#   inflating: ./content/odometria/esquerda/000229.png
#   inflating: ./content/odometria/esquerda/000230.png
#   inflating: ./content/odometria/esquerda/000231.png
#   inflating: ./content/odometria/esquerda/000232.png
#   inflating: ./content/odometria/esquerda/000233.png
#   inflating: ./content/odometria/esquerda/000234.png
#   inflating: ./content/odometria/esquerda/000235.png
#   inflating: ./content/odometria/esquerda/000236.png
#   inflating: ./content/odometria/esquerda/000237.png
#   inflating: ./content/odometria/esquerda/000238.png
#   inflating: ./content/odometria/esquerda/000239.png
#   inflating: ./content/odometria/esquerda/000240.png
#   inflating: ./content/odometria/esquerda/000241.png
#   inflating: ./content/odometria/esquerda/000242.png
#   inflating: ./content/odometria/esquerda/000243.png
#   inflating: ./content/odometria/esquerda/000244.png
#   inflating: ./content/odometria/esquerda/000245.png
#   inflating: ./content/odometria/esquerda/000246.png
#   inflating: ./content/odometria/esquerda/000247.png
#   inflating: ./content/odometria/esquerda/000248.png
#   inflating: ./content/odometria/esquerda/000249.png
#   inflating: ./content/odometria/esquerda/000250.png
#   inflating: ./content/odometria/esquerda/000251.png
#   inflating: ./content/odometria/esquerda/000252.png
#   inflating: ./content/odometria/esquerda/000253.png
#   inflating: ./content/odometria/esquerda/000254.png
#   inflating: ./content/odometria/esquerda/000255.png
#   inflating: ./content/odometria/esquerda/000256.png
#   inflating: ./content/odometria/esquerda/000257.png
#   inflating: ./content/odometria/esquerda/000258.png
#   inflating: ./content/odometria/esquerda/000259.png
#   inflating: ./content/odometria/esquerda/000260.png
#   inflating: ./content/odometria/esquerda/000261.png
#   inflating: ./content/odometria/esquerda/000262.png
#   inflating: ./content/odometria/esquerda/000263.png
#   inflating: ./content/odometria/esquerda/000264.png
#   inflating: ./content/odometria/esquerda/000265.png
#   inflating: ./content/odometria/esquerda/000266.png
#   inflating: ./content/odometria/esquerda/000267.png
#   inflating: ./content/odometria/esquerda/000268.png
#   inflating: ./content/odometria/esquerda/000269.png
#   inflating: ./content/odometria/esquerda/000270.png
#   inflating: ./content/odometria/esquerda/000271.png
#   inflating: ./content/odometria/esquerda/000272.png
#   inflating: ./content/odometria/esquerda/000273.png
#   inflating: ./content/odometria/esquerda/000274.png
#   inflating: ./content/odometria/esquerda/000275.png
#   inflating: ./content/odometria/esquerda/000276.png
#   inflating: ./content/odometria/esquerda/000277.png
#   inflating: ./content/odometria/esquerda/000278.png
#   inflating: ./content/odometria/esquerda/000279.png
#   inflating: ./content/odometria/esquerda/000280.png
#   inflating: ./content/odometria/esquerda/000281.png
#   inflating: ./content/odometria/esquerda/000282.png
#   inflating: ./content/odometria/esquerda/000283.png
#   inflating: ./content/odometria/esquerda/000284.png
#   inflating: ./content/odometria/esquerda/000285.png
#   inflating: ./content/odometria/esquerda/000286.png
#   inflating: ./content/odometria/esquerda/000287.png
#   inflating: ./content/odometria/esquerda/000288.png
#   inflating: ./content/odometria/esquerda/000289.png
#   inflating: ./content/odometria/esquerda/000290.png
#   inflating: ./content/odometria/esquerda/000291.png
#   inflating: ./content/odometria/esquerda/000292.png
#   inflating: ./content/odometria/esquerda/000293.png
#   inflating: ./content/odometria/esquerda/000294.png
#   inflating: ./content/odometria/esquerda/000295.png
#   inflating: ./content/odometria/esquerda/000296.png
#   inflating: ./content/odometria/esquerda/000297.png
#   inflating: ./content/odometria/esquerda/000298.png
#   inflating: ./content/odometria/esquerda/000299.png
#   inflating: ./content/odometria/esquerda/000300.png
#   inflating: ./content/odometria/esquerda/000301.png
#   inflating: ./content/odometria/esquerda/000302.png
#   inflating: ./content/odometria/esquerda/000303.png
#   inflating: ./content/odometria/esquerda/000304.png
#   inflating: ./content/odometria/esquerda/000305.png
#   inflating: ./content/odometria/esquerda/000306.png
#   inflating: ./content/odometria/esquerda/000307.png
#   inflating: ./content/odometria/esquerda/000308.png
#   inflating: ./content/odometria/esquerda/000309.png
#   inflating: ./content/odometria/esquerda/000310.png
#   inflating: ./content/odometria/esquerda/000311.png
#   inflating: ./content/odometria/esquerda/000312.png
#   inflating: ./content/odometria/esquerda/000313.png
#   inflating: ./content/odometria/esquerda/000314.png
#   inflating: ./content/odometria/esquerda/000315.png
#   inflating: ./content/odometria/esquerda/000316.png
#   inflating: ./content/odometria/esquerda/000317.png
#   inflating: ./content/odometria/esquerda/000318.png
#   inflating: ./content/odometria/esquerda/000319.png
#   inflating: ./content/odometria/esquerda/000320.png
#   inflating: ./content/odometria/esquerda/000321.png
#   inflating: ./content/odometria/esquerda/000322.png
#   inflating: ./content/odometria/esquerda/000323.png
#   inflating: ./content/odometria/esquerda/000324.png
#   inflating: ./content/odometria/esquerda/000325.png
#   inflating: ./content/odometria/esquerda/000326.png
#   inflating: ./content/odometria/esquerda/000327.png
#   inflating: ./content/odometria/esquerda/000328.png
#   inflating: ./content/odometria/esquerda/000329.png
#   inflating: ./content/odometria/esquerda/000330.png
#   inflating: ./content/odometria/esquerda/000331.png
#   inflating: ./content/odometria/esquerda/000332.png
#   inflating: ./content/odometria/esquerda/000333.png
#   inflating: ./content/odometria/esquerda/000334.png
#   inflating: ./content/odometria/esquerda/000335.png
#   inflating: ./content/odometria/esquerda/000336.png
#   inflating: ./content/odometria/esquerda/000337.png
#   inflating: ./content/odometria/esquerda/000338.png
#   inflating: ./content/odometria/esquerda/000339.png
#   inflating: ./content/odometria/esquerda/000340.png
#   inflating: ./content/odometria/esquerda/000341.png
#   inflating: ./content/odometria/esquerda/000342.png
#   inflating: ./content/odometria/esquerda/000343.png
#   inflating: ./content/odometria/esquerda/000344.png
#   inflating: ./content/odometria/esquerda/000345.png
#   inflating: ./content/odometria/esquerda/000346.png
#   inflating: ./content/odometria/esquerda/000347.png
#   inflating: ./content/odometria/esquerda/000348.png
#   inflating: ./content/odometria/esquerda/000349.png
#   inflating: ./content/odometria/esquerda/000350.png
#   inflating: ./content/odometria/esquerda/000351.png
#   inflating: ./content/odometria/esquerda/000352.png
#   inflating: ./content/odometria/esquerda/000353.png
#   inflating: ./content/odometria/esquerda/000354.png
#   inflating: ./content/odometria/esquerda/000355.png
#   inflating: ./content/odometria/esquerda/000356.png
#   inflating: ./content/odometria/esquerda/000357.png
#   inflating: ./content/odometria/esquerda/000358.png
#   inflating: ./content/odometria/esquerda/000359.png
#   inflating: ./content/odometria/esquerda/000360.png
#   inflating: ./content/odometria/esquerda/000361.png
#   inflating: ./content/odometria/esquerda/000362.png
#   inflating: ./content/odometria/esquerda/000363.png
#   inflating: ./content/odometria/esquerda/000364.png
#   inflating: ./content/odometria/esquerda/000365.png
#   inflating: ./content/odometria/esquerda/000366.png
#   inflating: ./content/odometria/esquerda/000367.png
#   inflating: ./content/odometria/esquerda/000368.png
#   inflating: ./content/odometria/esquerda/000369.png
#   inflating: ./content/odometria/esquerda/000370.png
#   inflating: ./content/odometria/esquerda/000371.png
#   inflating: ./content/odometria/esquerda/000372.png
#   inflating: ./content/odometria/esquerda/000373.png
#   inflating: ./content/odometria/esquerda/000374.png
#   inflating: ./content/odometria/esquerda/000375.png
#   inflating: ./content/odometria/esquerda/000376.png
#   inflating: ./content/odometria/esquerda/000377.png
#   inflating: ./content/odometria/esquerda/000378.png
#   inflating: ./content/odometria/esquerda/000379.png
#   inflating: ./content/odometria/esquerda/000380.png
#   inflating: ./content/odometria/esquerda/000381.png
#   inflating: ./content/odometria/esquerda/000382.png
#   inflating: ./content/odometria/esquerda/000383.png
#   inflating: ./content/odometria/esquerda/000384.png
#   inflating: ./content/odometria/esquerda/000385.png
#   inflating: ./content/odometria/esquerda/000386.png
#   inflating: ./content/odometria/esquerda/000387.png
#   inflating: ./content/odometria/esquerda/000388.png
#   inflating: ./content/odometria/esquerda/000389.png
#   inflating: ./content/odometria/esquerda/000390.png
#   inflating: ./content/odometria/esquerda/000391.png
#   inflating: ./content/odometria/esquerda/000392.png
#   inflating: ./content/odometria/esquerda/000393.png
#   inflating: ./content/odometria/esquerda/000394.png
#   inflating: ./content/odometria/esquerda/000395.png
#   inflating: ./content/odometria/esquerda/000396.png
#   inflating: ./content/odometria/esquerda/000397.png
#   inflating: ./content/odometria/esquerda/000398.png
#   inflating: ./content/odometria/esquerda/000399.png
#   inflating: ./content/odometria/esquerda/000400.png
#   inflating: ./content/odometria/esquerda/000401.png
#   inflating: ./content/odometria/esquerda/000402.png
#   inflating: ./content/odometria/esquerda/000403.png
#   inflating: ./content/odometria/esquerda/000404.png
#   inflating: ./content/odometria/esquerda/000405.png
#   inflating: ./content/odometria/esquerda/000406.png
#   inflating: ./content/odometria/esquerda/000407.png
#   inflating: ./content/odometria/esquerda/000408.png
#   inflating: ./content/odometria/esquerda/000409.png
#   inflating: ./content/odometria/esquerda/000410.png
#   inflating: ./content/odometria/esquerda/000411.png
#   inflating: ./content/odometria/esquerda/000412.png
#   inflating: ./content/odometria/esquerda/000413.png
#   inflating: ./content/odometria/esquerda/000414.png
#   inflating: ./content/odometria/esquerda/000415.png
#   inflating: ./content/odometria/esquerda/000416.png
#   inflating: ./content/odometria/esquerda/000417.png
#   inflating: ./content/odometria/esquerda/000418.png
#   inflating: ./content/odometria/esquerda/000419.png
#   inflating: ./content/odometria/esquerda/000420.png
#   inflating: ./content/odometria/esquerda/000421.png
#   inflating: ./content/odometria/esquerda/000422.png
#   inflating: ./content/odometria/esquerda/000423.png
#   inflating: ./content/odometria/esquerda/000424.png
#   inflating: ./content/odometria/esquerda/000425.png
#   inflating: ./content/odometria/esquerda/000426.png
#   inflating: ./content/odometria/esquerda/000427.png
#   inflating: ./content/odometria/esquerda/000428.png
#   inflating: ./content/odometria/esquerda/000429.png
#   inflating: ./content/odometria/esquerda/000430.png
#   inflating: ./content/odometria/esquerda/000431.png
#   inflating: ./content/odometria/esquerda/000432.png
#   inflating: ./content/odometria/esquerda/000433.png
#   inflating: ./content/odometria/esquerda/000434.png
#   inflating: ./content/odometria/esquerda/000435.png
#   inflating: ./content/odometria/esquerda/000436.png
#   inflating: ./content/odometria/esquerda/000437.png
#   inflating: ./content/odometria/esquerda/000438.png
#   inflating: ./content/odometria/esquerda/000439.png
#   inflating: ./content/odometria/esquerda/000440.png
#   inflating: ./content/odometria/esquerda/000441.png
#   inflating: ./content/odometria/esquerda/000442.png
#   inflating: ./content/odometria/esquerda/000443.png
#   inflating: ./content/odometria/esquerda/000444.png
#   inflating: ./content/odometria/esquerda/000445.png
#   inflating: ./content/odometria/esquerda/000446.png
#   inflating: ./content/odometria/esquerda/000447.png
#   inflating: ./content/odometria/esquerda/000448.png
#   inflating: ./content/odometria/esquerda/000449.png
#   inflating: ./content/odometria/esquerda/000450.png
#   inflating: ./content/odometria/esquerda/000451.png
#   inflating: ./content/odometria/esquerda/000452.png
#   inflating: ./content/odometria/esquerda/000453.png
#   inflating: ./content/odometria/esquerda/000454.png
#   inflating: ./content/odometria/esquerda/000455.png
#   inflating: ./content/odometria/esquerda/000456.png
#   inflating: ./content/odometria/esquerda/000457.png
#   inflating: ./content/odometria/esquerda/000458.png
#   inflating: ./content/odometria/esquerda/000459.png
#   inflating: ./content/odometria/esquerda/000460.png
#   inflating: ./content/odometria/esquerda/000461.png
#   inflating: ./content/odometria/esquerda/000462.png
#   inflating: ./content/odometria/esquerda/000463.png
#   inflating: ./content/odometria/esquerda/000464.png
#   inflating: ./content/odometria/esquerda/000465.png
#   inflating: ./content/odometria/esquerda/000466.png
#   inflating: ./content/odometria/esquerda/000467.png
#   inflating: ./content/odometria/esquerda/000468.png
#   inflating: ./content/odometria/esquerda/000469.png
#   inflating: ./content/odometria/esquerda/000470.png
#   inflating: ./content/odometria/esquerda/000471.png
#   inflating: ./content/odometria/esquerda/000472.png
#   inflating: ./content/odometria/esquerda/000473.png
#   inflating: ./content/odometria/esquerda/000474.png
#   inflating: ./content/odometria/esquerda/000475.png
#   inflating: ./content/odometria/esquerda/000476.png
#   inflating: ./content/odometria/esquerda/000477.png
#   inflating: ./content/odometria/esquerda/000478.png
#   inflating: ./content/odometria/esquerda/000479.png
#   inflating: ./content/odometria/esquerda/000480.png
#   inflating: ./content/odometria/esquerda/000481.png
#   inflating: ./content/odometria/esquerda/000482.png
#   inflating: ./content/odometria/esquerda/000483.png
#   inflating: ./content/odometria/esquerda/000484.png
#   inflating: ./content/odometria/esquerda/000485.png
#   inflating: ./content/odometria/esquerda/000486.png
#   inflating: ./content/odometria/esquerda/000487.png
#   inflating: ./content/odometria/esquerda/000488.png
#   inflating: ./content/odometria/esquerda/000489.png
#   inflating: ./content/odometria/esquerda/000490.png
#   inflating: ./content/odometria/esquerda/000491.png
#   inflating: ./content/odometria/esquerda/000492.png
#   inflating: ./content/odometria/esquerda/000493.png
#   inflating: ./content/odometria/esquerda/000494.png
#   inflating: ./content/odometria/esquerda/000495.png
#   inflating: ./content/odometria/esquerda/000496.png
#   inflating: ./content/odometria/esquerda/000497.png
#   inflating: ./content/odometria/esquerda/000498.png
#   inflating: ./content/odometria/esquerda/000499.png
#   inflating: ./content/odometria/esquerda/000500.png
#   inflating: ./content/odometria/esquerda/000501.png
#   inflating: ./content/odometria/esquerda/000502.png
#   inflating: ./content/odometria/esquerda/000503.png
#   inflating: ./content/odometria/esquerda/000504.png
#   inflating: ./content/odometria/esquerda/000505.png
#   inflating: ./content/odometria/esquerda/000506.png
#   inflating: ./content/odometria/esquerda/000507.png
#   inflating: ./content/odometria/esquerda/000508.png
#   inflating: ./content/odometria/esquerda/000509.png
#   inflating: ./content/odometria/esquerda/000510.png
#   inflating: ./content/odometria/esquerda/000511.png
#   inflating: ./content/odometria/esquerda/000512.png
#   inflating: ./content/odometria/esquerda/000513.png
#   inflating: ./content/odometria/esquerda/000514.png
#   inflating: ./content/odometria/esquerda/000515.png
#   inflating: ./content/odometria/esquerda/000516.png
#   inflating: ./content/odometria/esquerda/000517.png
#   inflating: ./content/odometria/esquerda/000518.png
#   inflating: ./content/odometria/esquerda/000519.png
#   inflating: ./content/odometria/esquerda/000520.png
#   inflating: ./content/odometria/esquerda/000521.png
#   inflating: ./content/odometria/esquerda/000522.png
#   inflating: ./content/odometria/esquerda/000523.png
#   inflating: ./content/odometria/esquerda/000524.png
#   inflating: ./content/odometria/esquerda/000525.png
#   inflating: ./content/odometria/esquerda/000526.png
#   inflating: ./content/odometria/esquerda/000527.png
#   inflating: ./content/odometria/esquerda/000528.png
#   inflating: ./content/odometria/esquerda/000529.png
#   inflating: ./content/odometria/esquerda/000530.png
#   inflating: ./content/odometria/esquerda/000531.png
#   inflating: ./content/odometria/esquerda/000532.png
#   inflating: ./content/odometria/esquerda/000533.png
#   inflating: ./content/odometria/esquerda/000534.png
#   inflating: ./content/odometria/esquerda/000535.png
#   inflating: ./content/odometria/esquerda/000536.png
#   inflating: ./content/odometria/esquerda/000537.png
#   inflating: ./content/odometria/esquerda/000538.png
#   inflating: ./content/odometria/esquerda/000539.png
#   inflating: ./content/odometria/esquerda/000540.png
#   inflating: ./content/odometria/esquerda/000541.png
#   inflating: ./content/odometria/esquerda/000542.png
#   inflating: ./content/odometria/esquerda/000543.png
#   inflating: ./content/odometria/esquerda/000544.png
#   inflating: ./content/odometria/esquerda/000545.png
#   inflating: ./content/odometria/esquerda/000546.png
#   inflating: ./content/odometria/esquerda/000547.png
#   inflating: ./content/odometria/esquerda/000548.png
#   inflating: ./content/odometria/esquerda/000549.png
#   inflating: ./content/odometria/esquerda/000550.png
#   inflating: ./content/odometria/esquerda/000551.png
#   inflating: ./content/odometria/esquerda/000552.png
#   inflating: ./content/odometria/esquerda/000553.png
#   inflating: ./content/odometria/esquerda/000554.png
#   inflating: ./content/odometria/esquerda/000555.png
#   inflating: ./content/odometria/esquerda/000556.png
#   inflating: ./content/odometria/esquerda/000557.png
#   inflating: ./content/odometria/esquerda/000558.png
#   inflating: ./content/odometria/esquerda/000559.png
#   inflating: ./content/odometria/esquerda/000560.png
#   inflating: ./content/odometria/esquerda/000561.png
#   inflating: ./content/odometria/esquerda/000562.png
#   inflating: ./content/odometria/esquerda/000563.png
#   inflating: ./content/odometria/esquerda/000564.png
#   inflating: ./content/odometria/esquerda/000565.png
#   inflating: ./content/odometria/esquerda/000566.png
#   inflating: ./content/odometria/esquerda/000567.png
#   inflating: ./content/odometria/esquerda/000568.png
#   inflating: ./content/odometria/esquerda/000569.png
#   inflating: ./content/odometria/esquerda/000570.png
#   inflating: ./content/odometria/esquerda/000571.png
#   inflating: ./content/odometria/esquerda/000572.png
#   inflating: ./content/odometria/esquerda/000573.png
#   inflating: ./content/odometria/esquerda/000574.png
#   inflating: ./content/odometria/esquerda/000575.png
#   inflating: ./content/odometria/esquerda/000576.png
#   inflating: ./content/odometria/esquerda/000577.png
#   inflating: ./content/odometria/esquerda/000578.png
#   inflating: ./content/odometria/esquerda/000579.png
#   inflating: ./content/odometria/esquerda/000580.png
#   inflating: ./content/odometria/esquerda/000581.png
#   inflating: ./content/odometria/esquerda/000582.png
#   inflating: ./content/odometria/esquerda/000583.png
#   inflating: ./content/odometria/esquerda/000584.png
#   inflating: ./content/odometria/esquerda/000585.png
#   inflating: ./content/odometria/esquerda/000586.png
#   inflating: ./content/odometria/esquerda/000587.png
#   inflating: ./content/odometria/esquerda/000588.png
#   inflating: ./content/odometria/esquerda/000589.png
#   inflating: ./content/odometria/esquerda/000590.png
#   inflating: ./content/odometria/esquerda/000591.png
#   inflating: ./content/odometria/esquerda/000592.png
#   inflating: ./content/odometria/esquerda/000593.png
#   inflating: ./content/odometria/esquerda/000594.png
#   inflating: ./content/odometria/esquerda/000595.png
#   inflating: ./content/odometria/esquerda/000596.png
#   inflating: ./content/odometria/esquerda/000597.png
#   inflating: ./content/odometria/esquerda/000598.png
#   inflating: ./content/odometria/esquerda/000599.png
#   inflating: ./content/odometria/esquerda/000600.png
#   inflating: ./content/odometria/esquerda/000601.png
#   inflating: ./content/odometria/esquerda/000602.png
#   inflating: ./content/odometria/esquerda/000603.png
#   inflating: ./content/odometria/esquerda/000604.png
#   inflating: ./content/odometria/esquerda/000605.png
#   inflating: ./content/odometria/esquerda/000606.png
#   inflating: ./content/odometria/esquerda/000607.png
#   inflating: ./content/odometria/esquerda/000608.png
#   inflating: ./content/odometria/esquerda/000609.png
#   inflating: ./content/odometria/esquerda/000610.png
#   inflating: ./content/odometria/esquerda/000611.png
#   inflating: ./content/odometria/esquerda/000612.png
#   inflating: ./content/odometria/esquerda/000613.png
#   inflating: ./content/odometria/esquerda/000614.png
#   inflating: ./content/odometria/esquerda/000615.png
#   inflating: ./content/odometria/esquerda/000616.png
#   inflating: ./content/odometria/esquerda/000617.png
#   inflating: ./content/odometria/esquerda/000618.png
#   inflating: ./content/odometria/esquerda/000619.png
#   inflating: ./content/odometria/esquerda/000620.png
#   inflating: ./content/odometria/esquerda/000621.png
#   inflating: ./content/odometria/esquerda/000622.png
#   inflating: ./content/odometria/esquerda/000623.png
#   inflating: ./content/odometria/esquerda/000624.png
#   inflating: ./content/odometria/esquerda/000625.png
#   inflating: ./content/odometria/esquerda/000626.png
#   inflating: ./content/odometria/esquerda/000627.png
#   inflating: ./content/odometria/esquerda/000628.png
#   inflating: ./content/odometria/esquerda/000629.png
#   inflating: ./content/odometria/esquerda/000630.png
#   inflating: ./content/odometria/esquerda/000631.png
#   inflating: ./content/odometria/esquerda/000632.png
#   inflating: ./content/odometria/esquerda/000633.png
#   inflating: ./content/odometria/esquerda/000634.png
#   inflating: ./content/odometria/esquerda/000635.png
#   inflating: ./content/odometria/esquerda/000636.png
#   inflating: ./content/odometria/esquerda/000637.png
#   inflating: ./content/odometria/esquerda/000638.png
#   inflating: ./content/odometria/esquerda/000639.png
#   inflating: ./content/odometria/esquerda/000640.png
#   inflating: ./content/odometria/esquerda/000641.png
#   inflating: ./content/odometria/esquerda/000642.png
#   inflating: ./content/odometria/esquerda/000643.png
#   inflating: ./content/odometria/esquerda/000644.png
#   inflating: ./content/odometria/esquerda/000645.png
#   inflating: ./content/odometria/esquerda/000646.png
#   inflating: ./content/odometria/esquerda/000647.png
#   inflating: ./content/odometria/esquerda/000648.png
#   inflating: ./content/odometria/esquerda/000649.png
#   inflating: ./content/odometria/esquerda/000650.png
#   inflating: ./content/odometria/esquerda/000651.png
#   inflating: ./content/odometria/esquerda/000652.png
#   inflating: ./content/odometria/esquerda/000653.png
#   inflating: ./content/odometria/esquerda/000654.png
#   inflating: ./content/odometria/esquerda/000655.png
#   inflating: ./content/odometria/esquerda/000656.png
#   inflating: ./content/odometria/esquerda/000657.png
#   inflating: ./content/odometria/esquerda/000658.png
#   inflating: ./content/odometria/esquerda/000659.png
#   inflating: ./content/odometria/esquerda/000660.png
#   inflating: ./content/odometria/esquerda/000661.png
#   inflating: ./content/odometria/esquerda/000662.png
#   inflating: ./content/odometria/esquerda/000663.png
#   inflating: ./content/odometria/esquerda/000664.png
#   inflating: ./content/odometria/esquerda/000665.png
#   inflating: ./content/odometria/esquerda/000666.png
#   inflating: ./content/odometria/esquerda/000667.png
#   inflating: ./content/odometria/esquerda/000668.png
#   inflating: ./content/odometria/esquerda/000669.png
#   inflating: ./content/odometria/esquerda/000670.png
#   inflating: ./content/odometria/esquerda/000671.png
#   inflating: ./content/odometria/esquerda/000672.png
#   inflating: ./content/odometria/esquerda/000673.png
#   inflating: ./content/odometria/esquerda/000674.png
#   inflating: ./content/odometria/esquerda/000675.png
#   inflating: ./content/odometria/esquerda/000676.png
#   inflating: ./content/odometria/esquerda/000677.png
#   inflating: ./content/odometria/esquerda/000678.png
#   inflating: ./content/odometria/esquerda/000679.png
#   inflating: ./content/odometria/esquerda/000680.png
#   inflating: ./content/odometria/esquerda/000681.png
#   inflating: ./content/odometria/esquerda/000682.png
#   inflating: ./content/odometria/esquerda/000683.png
#   inflating: ./content/odometria/esquerda/000684.png
#   inflating: ./content/odometria/esquerda/000685.png
#   inflating: ./content/odometria/esquerda/000686.png
#   inflating: ./content/odometria/esquerda/000687.png
#   inflating: ./content/odometria/esquerda/000688.png
#   inflating: ./content/odometria/esquerda/000689.png
#   inflating: ./content/odometria/esquerda/000690.png
#   inflating: ./content/odometria/esquerda/000691.png
#   inflating: ./content/odometria/esquerda/000692.png
#   inflating: ./content/odometria/esquerda/000693.png
#   inflating: ./content/odometria/esquerda/000694.png
#   inflating: ./content/odometria/esquerda/000695.png
#   inflating: ./content/odometria/esquerda/000696.png
#   inflating: ./content/odometria/esquerda/000697.png
#   inflating: ./content/odometria/esquerda/000698.png
#   inflating: ./content/odometria/esquerda/000699.png
#   inflating: ./content/odometria/esquerda/000700.png
#    creating: ./content/odometria/direita/
#   inflating: ./content/odometria/direita/000000.png
#   inflating: ./content/odometria/direita/000001.png
#   inflating: ./content/odometria/direita/000002.png
#   inflating: ./content/odometria/direita/000003.png
#   inflating: ./content/odometria/direita/000004.png
#   inflating: ./content/odometria/direita/000005.png
#   inflating: ./content/odometria/direita/000006.png
#   inflating: ./content/odometria/direita/000007.png
#   inflating: ./content/odometria/direita/000008.png
#   inflating: ./content/odometria/direita/000009.png
#   inflating: ./content/odometria/direita/000010.png
#   inflating: ./content/odometria/direita/000011.png
#   inflating: ./content/odometria/direita/000012.png
#   inflating: ./content/odometria/direita/000013.png
#   inflating: ./content/odometria/direita/000014.png
#   inflating: ./content/odometria/direita/000015.png
#   inflating: ./content/odometria/direita/000016.png
#   inflating: ./content/odometria/direita/000017.png
#   inflating: ./content/odometria/direita/000018.png
#   inflating: ./content/odometria/direita/000681.png
#   inflating: ./content/odometria/direita/000682.png
#   inflating: ./content/odometria/direita/000683.png
#   inflating: ./content/odometria/direita/000684.png
#   inflating: ./content/odometria/direita/000685.png
#   inflating: ./content/odometria/direita/000686.png
#   inflating: ./content/odometria/direita/000687.png
#   inflating: ./content/odometria/direita/000688.png
#   inflating: ./content/odometria/direita/000689.png
#   inflating: ./content/odometria/direita/000690.png
#   inflating: ./content/odometria/direita/000691.png
#   inflating: ./content/odometria/direita/000692.png
#   inflating: ./content/odometria/direita/000693.png
#   inflating: ./content/odometria/direita/000694.png
#   inflating: ./content/odometria/direita/000695.png
#   inflating: ./content/odometria/direita/000696.png
#   inflating: ./content/odometria/direita/000697.png
#   inflating: ./content/odometria/direita/000698.png
#   inflating: ./content/odometria/direita/000699.png
#   inflating: ./content/odometria/direita/000700.png
#   inflating: ./content/odometria/tempos.txt
#   inflating: ./content/odometria/calib.txt
#   inflating: ./content/odometria/referencia.txt

# %% [markdown]
# Vamos carregar parte das imagens e dos dados de tempos, de calibração e de referência.

# %%
N = 100
tempos = np.loadtxt(str(root_path/'tempos.txt'))
imgs_esq = [cv2.imread(str(p), cv2.IMREAD_ANYCOLOR) for p in sorted((root_path/'esquerda').glob('*.png'))[:N]]
proj_esq = np.loadtxt(str(root_path/'calib.txt'), dtype=np.float32)[0].reshape(3, 4)
imgs_dir = [cv2.imread(str(p), cv2.IMREAD_ANYCOLOR) for p in sorted((root_path/'direita').glob('*.png'))[:N]]
proj_dir = np.loadtxt(str(root_path/'calib.txt'), dtype=np.float32)[1].reshape(3, 4)
refs = np.loadtxt(str(root_path/'referencia.txt'), dtype=np.float32).reshape(-1, 3, 4)

# %% [markdown]
# ## Operações de Odometria
#
# Para o caso da odometria monocular, é necessário um parâmetro de escala para conseguir estabelecer a distância percorrida (nas unidades de comprimento) entre dois quadros. Esse fator de escala pode ser oriundo de sensores inerciais ou de ainda algum outro sensor associade à unidade de comprimento (como um velocímetro). Dessa forma, vamos acabar derivando a velocidade a partir dos dados de posição de referência (que foram obtidas de fusão de sensores inerciais e de posição).
#
# Implemente a função abaixo que deriva a velocidade a partir das matrizes de pose. (1 ponto)
#
# <details><summary><b>Dica</b></summary>
# <p>
# Use apenas indexação de matrizes do numpy e também `np.linalg.norm` aplicado apenas em um eixo `axis` específico.
# </p>
# </details>

# %%
def calcula_velocidade(posicoes, tempos):
    """
    Calcula a velocidade a partir de matrizes de pose e de um vetor de tempo por meio de diferenças finitas
    :param posicoes: Matrizes de pose (n, 3, 4) em metros [R_mat | T_vec]
    :param tempos: Vetor do tempo (n, ) associada a cada posição em segundos, crescente
    Retorna vetor de velocidades lineares em m/s calculada por diferenças finitas progressivas (diferença da próxima
    posição para a atual).
    """
    velocidades = np.linalg.norm(posicoes[1:, :, 3] - posicoes[:-1, :, 3], axis=1)/(tempos[1:] - tempos[:-1])
    return velocidades

# %%
velos = calcula_velocidade(refs[:11], tempos[:11])
assert np.linalg.norm(velos - np.array([1.22559295, 1.37714263, 1.58089024, 1.71854421, 1.85536711,
       1.99962678, 2.11304293, 2.24617   , 2.38809648, 2.5471701 ])) < 1e-4
velocidades = calcula_velocidade(refs[:len(tempos)], tempos)

# %% [markdown]
# Dados deste laboratório foram extraídos do [KITTI](https://www.cvlibs.net/datasets/kitti/) (Karlsruhe Institute of Technology and Toyota Technological Institute) e servem como benchmark de algoritmos de localização para carros autônomos (apesar de que para um dataset de mais de 10 anos, já tivemos uma significativa evolução dos sensores).
#
# Neste laboratório iremos utilizar apenas as câmeras mono da esquerda (Cam 0) e da direita (Cam 1), além dos dados de calibração e de referência (para comparação). Perceba que o referencial da câmera da esquerda está próximo ao centro de massa o do carro (a menos da altura) e será utilizado como o sistema de coordenadas do carro.
#
# Perceba que a direção do Z é a frente, a direção do X é da lateral direita do carro e a direção do Y é para baixo.
#
# ![Posição das câmeras no carro](https://www.cvlibs.net/datasets/kitti/images/setup_top_view.png)
#
# As imagens estéreo já foram retificadas (`R_mat = np.eye(3)`) e des-distorcidas, de tal forma que a há uma única componente de translação horizontal entre as câmeras. Encontre esse vetor a partir da matriz de projeção (a matriz que leva pontos no espaço 3d para pontos homogêneos em pixels 2d, resultado de `mtx @ [R_mat | t_vec]`) e também a matrix intrínseca `mtx`. (1 ponto)
#
# <details><summary><b>Dica</b></summary>
# <p>
# Use apenas indexação de matrizes do numpy.
# </p>
# </details>

# %%
def matriz_projecao_para_mtx_T(matriz_projecao):
    """
    Decompõe a matrix de projeção na matriz intríseca e no vetor de translação, considerando um sistema de câmeras
    já retificadas horizontalmente (não há rotação e apenas translação horizontal)
    :param matriz_projecao: matriz de projeção 3x4 resultado de mtx @ [R_mat | t_vec]
    Retorna a matriz_intrinseca mtx 3x3 em pixels e o vetor de translação t_vec 3x1 em metros.
    Na resposta não é para chamar nenhuma função do OpenCV, é para calcular manualmente
    """
    matriz_intrinseca = matriz_projecao[:, :3]
    vetor_translacao = np.reshape((np.linalg.inv(matriz_intrinseca) @ matriz_projecao[:, 3]), (3,1))
    return matriz_intrinseca, vetor_translacao

# %%
P = np.array([[50, 0, 100, 100],[0, 50, 100, 0],[0, 0, 1, 0]])
mtx, t_vec = matriz_projecao_para_mtx_T(P)
assert np.all(mtx == np.array([[50, 0, 100], [0, 50, 100], [0, 0, 1]]))
assert np.all(t_vec == np.array([[2],[0],[0]]))

mtx_esq, t_esq = matriz_projecao_para_mtx_T(proj_esq)
mtx_dir, t_dir = matriz_projecao_para_mtx_T(proj_dir)

# %% [markdown]
# Outra operação essencial de odometria é reconstruir a trajetória absoluta a partir dos vetores de deslocamento e das matrizes de rotação relativas extraídas de cada frame. Observe que é nessa operação que os erros se propagam e aumentam com o tempo (drifting) uma vez que se realiza a soma (vetorial) dos deslocamentos.
#
# Assim, implemente a função abaixo que realiza essa transformação de coordenadas encadeada para obter a trajetória com relação à pose inicial. (1 ponto)
#
# <details><summary><b>Dica</b></summary>
# <p>
# Basta usar multiplicação de matrizes no numpy, o operador `a @ b` que é equivalente a `np.matmul(a, b)`. Não vai me confundir a rotação (pensando que é para calcular a inversa) e a translação (pensando que é para subtrair), as matrizes e os vetores já estão representados como deslocamentos (que levam do atual para o próximo).
# </p>
# </details>

# %%
def reconstroi_trajetoria(lista_matrizes_rotacao, lista_vetores_deslocamento):
    """
    Reconstroi a trajetória a partir da origem (a ser incluída como primeiro ponto da saída).
    :param lista_matrizes_rotacao: lista de matrizes de rotação 3x3 que descreve a rotação da próxima pose com 
                                   relação à atual
    :param lista_vetores_deslocamento: lista de vetores de deslocamento 3x1 que descreve o deslocamento da próxima 
                                   pose com relação à atual
    Retorna a lista de rotações e translações  com relação à origem.
    """
    lista_rotacao_absoluta = [np.eye(3)]
    for i, rotation in enumerate(lista_matrizes_rotacao):
        lista_rotacao_absoluta.append(lista_rotacao_absoluta[i]@rotation)
    lista_posicao_absoluta = [np.zeros((3, 1))]
    for i, translation in enumerate(lista_vetores_deslocamento):
        lista_posicao_absoluta.append(np.reshape(lista_posicao_absoluta[i] + lista_rotacao_absoluta[i]@translation, (3, 1)))

    return lista_rotacao_absoluta, lista_posicao_absoluta

# %%
rmats, tvecs = reconstroi_trajetoria([R.from_euler('XYZ',[0,np.pi/4,0]).as_matrix()]*8, [np.array([[0],[0],[1]])]*8)
assert np.linalg.norm(rmats[0] - np.eye(3)) < 1e-6
assert np.linalg.norm(tvecs[0] - np.zeros(3)) < 1e-6
assert np.linalg.norm(rmats[8] - np.eye(3)) < 1e-6
assert np.linalg.norm(tvecs[8] - np.zeros(3)) < 1e-6

# %% [markdown]
# Veja a trajetória de exemplo abaixo que se desloca 1 metro para a frente e vira 45º para a direita a cada passo:
#
# OBS: Seguindo a convenção do sistema de coordenadas do carro, plotamos os eixos X e Z

# %%
n = 16
rmats,tvecs=reconstroi_trajetoria([R.from_euler('XYZ',[0,2*np.pi/n,0]).as_matrix()]*n, [np.array([[0],[0],[1]])]*n)
plt.figure(figsize=(8, 8))
plt.plot([p[0,0] for p in tvecs], [p[2,0] for p in tvecs], 'o-')
plt.xlabel('Posição X (m)')
plt.ylabel('Posição Z (m)')
plt.show()

# %% [markdown]
# ## Odometria Monocular (com dados externos de velocidade)
#
# O passo mais simples da odometria é utilizar imagens apenas de uma câmera para conseguir estimar a pose relativa entre dois frames. O problema é que não é possível determinar o fator de escala entre as imagens, dessa forma é necessário conhecer ou a escala (distância) de pelo menos um ponto ou ainda a escala (distância) entre as duas poses, que no caso pode ser facilmente obtida conhecendo-se a velocidade.

# %% [markdown]
# O primeiro passo da odometria é calcular o deslocamento 2d entre os pontos projetados na imagem. Podemos fazer isso de forma esparsa, com um detector de features (que detecta pontos salientes na imagem com seus descritores) e um correlacionador dessas features, que tenta
#
# Outra alternativa que veremos a seguir é justamente calcular o fluxo óptico entre as duas imagens, selecionando apenas os pontos de maior distinção.

# %%
detector = cv2.ORB_create(nfeatures=4500, scaleFactor=1.19)
relacionador = cv2.FlannBasedMatcher(indexParams={
    'algorithm':6, 'table_number':6, 'key_size':12, 'multi_probe_level':1}, searchParams={'checks': 50})

def pegar_pontos_iguais(img1, img2):
    """
    Recebe duas imagens e retorna as coords. de pontos correspondentes nx2
    """
    pontos1, descritores1 = detector.detectAndCompute(img1, None)
    pontos2, descritores2 = detector.detectAndCompute(img2, None)
    relacoes = relacionador.knnMatch(descritores1, descritores2, k=2)
    relacoes_fortes = [r1 for r1, r2 in relacoes if r1.distance < 0.7 * r2.distance]
    pts1 = np.array([pontos1[r.queryIdx].pt for r in relacoes_fortes], dtype=np.float32)
    pts2 = np.array([pontos2[r.trainIdx].pt for r in relacoes_fortes], dtype=np.float32)
    return pts1, pts2

# %% [markdown]
# Veja abaixo, por exemplo, a relação encontrada para os pontos entre duas imagens consecutivas:
#
# Na realidade peguei uma imagem 3 quadros passados para ficar maiores os deslocamentos e também a rotação maior (para o corretor automático).

# %%
pts_fut, pts = pegar_pontos_iguais(imgs_esq[47], imgs_esq[44])
img = np.repeat(imgs_esq[44][:, :, None], 3, axis=-1)
for pfut, p in zip(pts_fut, pts): # Desenha uma linha ligando os pares de pontos
    cv2.line(img, np.uint(p), np.uint(pfut), (250, 250, 0))
PIL.Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1226x370 at 0x7FC495135DF0>

# %% [markdown]
# Como o primeiro passo em geral resulta em uma grande quantidade de outlier, no segundo passo de encontrar a matriz essencial (que é posteriormente decomposta na matriz de rotação e translação), utiliza-se o RANSAC.
#
# Relembrando que a matriz essencial ($\mathbf  {E}$) é o resultado do produto entre a matriz de rotação e a matriz de translação do produto vetorial $\mathbf  {E}=\mathbf  {R}\,[\mathbf  {t}]_{\times }$, onde $[\mathbf  {t}]_{\times }$ é a representação matricial da operação de produto vetorial:
#
# $\mathbf {a} \times \mathbf {b} =[\mathbf {a} ]_{\times }\mathbf {b} ={\begin{bmatrix}\,0&\!-a_{3}&\,\,a_{2}\\\,\,a_{3}&0&\!-a_{1}\\-a_{2}&\,\,a_{1}&\,0\end{bmatrix}}{\begin{bmatrix}b_{1}\\b_{2}\\b_{3}\end{bmatrix}}$
#
# Para estimar a matriz essencial são necessário pelo menos 8 pares de pontos (no mínimo é 7 mas 8 é mais estável). Dessa forma o RANSAC fará amostras aleatórias de 8 pares de pontos e calculará a matriz essencial (o modelo). As distâncias dos pontos até as suas linhas epipolares são utilizadas como limiar para determinar se um ponto é ou não outlier para o modelo. Assim, escolhe-se o modelo com a maior quantidade de inliers.
#
# Implemente a função abaixo que simplesmente chama a função `cv2.recoverPose` do OpenCV. (1 ponto)

# %%
def estima_rotacao_translacao(pts_futuro, pts_atual, mtx, metodo=cv2.USAC_ACCURATE, confianca=0.9999, dist=2):
    """
    Utiliza a função cv2.recoverPose que calcula a matriz essencial (e faz a sua decomposição na rotação e 
    translação) a partir dos pares de pontos. Utilize o método de cv2.USAC_ACCURATE, que é mais eficiente do
    que o velho RANSAC.
    :param pts_futuro: Matriz de pontos 2d nx2 na imagem futura
    :param pts_atual: Matriz de pontos 2d nx2 relacionados ao pts_futuro
    :param mtx: Matriz intrínseca da câmera, a imagem já foi des-distorcida
    :param confianca: Probabilidade de acerto do RANSAC
    :param dist: Limiar de distância entre o ponto e o modelo (linha epipolar) para considerar outlier
    Retorna a matriz de rotação e o vetor de translação normalizado, além da máscara dos inliers.
    """
    _, _, matriz_rotacao, direcao_translacao, inliers = cv2.recoverPose(
        pts_futuro, pts_atual, mtx, None, mtx, None, method=metodo, prob=confianca, threshold=dist
    )

    return matriz_rotacao, direcao_translacao, inliers

# %%
mtx_esq, t_esq = matriz_projecao_para_mtx_T(proj_esq)
pts_fut, pts = pegar_pontos_iguais(imgs_esq[47], imgs_esq[44])
rmat, tvec, mask = estima_rotacao_translacao(pts_fut, pts, mtx_esq)
assert np.linalg.norm(rmat - np.array(
       [[ 0.99590877,  0.00659954,  0.09012309],
        [-0.00645422,  0.99997736, -0.00190382],
        [-0.09013362,  0.00131436,  0.99592881]])) < 1e-2
assert np.linalg.norm(tvec - np.array(
       [[ 0.05638571],
        [-0.0194907 ],
        [ 0.9982188 ]])) < 1e-1

# %% [markdown]
# Veja como ficam os outliers (em vermelho)

# %%
img = np.repeat(imgs_esq[44][:, :, None], 3, axis=-1)
for pfut, p, inlier in zip(pts_fut, pts, mask.ravel()): # Desenha uma linha ligando os pares de pontos
    cor = (255, 0, 0)
    if inlier:
        cor = (0, 255, 0)
    cv2.line(img, np.int32(p), np.int32(pfut), cor)
PIL.Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1226x370 at 0x7FC491E5E100>

# %% [markdown]
# Agora vamos corrigir a escala do vetor de translação, dado a nossa velocidade estimada e um intervado de tempo. (1 ponto)

# %%
def corrige_escala(vetor_translacao, velocidade, delta_t):
    """
    Aplica a escala no vetor deslocamento, usando a aproximação de primeira ordem (linear).
    :param vetor_translacao: Vetor de translação/deslocamento 3x1
    :param velocidade: Escalar da velocidade (m/s)
    :param delta_t: Escalar do intervalo de tempo considerado (segundos)
    Retorna o vetor de translação dimensionalizado (m) pela velocidade
    """
    vetor_dimensionalizado = velocidade*delta_t*vetor_translacao
    return vetor_dimensionalizado

# %%
assert np.linalg.norm(corrige_escala(np.array([[3],[2],[8]]), 1, 1) - np.array([[3],[2],[8]])) < 1e-8

# %% [markdown]
# Finalmente juntamos todas as funções que implementamos até agora. Implemente a função abaixo. (3 pontos)

# %%
def odometria_mono(imgs, mtx, velocidades, tempos):
    """
    Recebe uma sequência de imagens tiradas de uma mesma câmera, e reconstroe a trajetória percorrida.
    Utilize a imagem imediatamente subsequente para estimar a pose relativa de cada imagem da sequência.
    :param imgs: lista de imagens de escala de cinza
    :param mtx: matriz intrínseca da câmera, a imagem já está des-distorcida
    :param velocidades: vetor de velocidades (m/s)
    :param tempos: vetor de tempos (s)
    Usa a função pegar_pontos_iguais que recebe duas imagens e retorna duas matrizes de pontos2d
    Retorna a trajetória percorrida, reconstruída tomando-se o primeiro quadro como a origem
    """
    lista_matrizes_rotacao = []
    lista_vetores_translacao = []
    for i in range(1, len(imgs)):
        rmat, tvec, _ = estima_rotacao_translacao(*pegar_pontos_iguais(imgs[i], imgs[i-1]), mtx)
        lista_matrizes_rotacao.append(rmat)
        lista_vetores_translacao.append(tvec)
    lista_vetores_deslocamento = [
        corrige_escala(vetor_translacao, velocidades[i], tempos[i+1] - tempos[i])
        for i, vetor_translacao in enumerate(lista_vetores_translacao)
    ]
    lista_rotacao_absoluta, lista_posicao_absoluta = reconstroi_trajetoria(lista_matrizes_rotacao, lista_vetores_deslocamento)
    return np.array(lista_rotacao_absoluta), np.array(lista_posicao_absoluta)

# %%
rotacoes, posicoes = odometria_mono(imgs_esq[:70], mtx_esq, velocidades[:69], tempos[:70])
assert np.linalg.norm(rotacoes[0] - np.eye(3)) < 1e-6
assert np.linalg.norm(posicoes[0] - np.zeros(3)) < 1e-6
assert np.linalg.norm(rotacoes[-1] - np.array(
      [[-0.5063042 ,  0.04474437,  0.8611933 ],
       [ 0.03299499,  0.9989269 , -0.03250242],
       [-0.8617235 ,  0.01195895, -0.5072372 ]])) < 5e-2
assert np.linalg.norm(posicoes[-1] - np.array(
      [[38.33941  ],
       [ 0.7189929],
       [ 2.756405 ]])) < 3.5

# %%
plt.figure(figsize=(16, 6))
plt.plot(posicoes[:, 0, 0], posicoes[:, 2, 0], 'b-o', label='Odometria')
plt.plot(refs[:len(posicoes), 0, 3], refs[:len(posicoes), 2, 3], 'g-x', label='Referência')
plt.legend()
plt.xlabel('Distância em X (m)')
plt.ylabel('Distância em Y (m)')
plt.axis('equal')
plt.show()

# %% [markdown]
# Podemos refazer todo o processo acima, substuindo a função que faz o rastreio 2d, de um caso de features detector por fluxo optico:

# %%
def pegar_pontos_fluxo_optico(img_fut, img):
    p = cv2.goodFeaturesToTrack(img, maxCorners=3200, qualityLevel=0.012, minDistance=8, blockSize=5)
    pfut, status, err = cv2.calcOpticalFlowPyrLK(img, img_fut, p, None, winSize=(15, 15))
    valid = status.ravel().astype(np.bool8)
    return pfut.reshape(-1, 2)[valid], p.reshape(-1, 2)[valid]

# %%
pts_fut, pts = pegar_pontos_fluxo_optico(imgs_esq[47], imgs_esq[46])
img = np.repeat(imgs_esq[46][:, :, None], 3, axis=-1)
for pfut, p in zip(pts_fut, pts): # Desenha uma linha ligando os pares de pontos
    cv2.line(img, np.int32(p), np.int32(pfut), (250, 250, 0))
print(len(pts))
PIL.Image.fromarray(img)
# Out:
# 1612
# <PIL.Image.Image image mode=RGB size=1226x370 at 0x7FC4950C8670>

# %% [markdown]
# Agora reimplemente a função acima, mas usando a função `pegar_pontos_fluxo_optico` para estabelecer o vínculo 2d. Perceba o que acontece com o resultado. (1 ponto)

# %%
def odometria_mono_LK(imgs, mtx, velocidades, tempos):
    """
    Recebe uma sequência de imagens tiradas de uma mesma câmera, e reconstroe a trajetória percorrida.
    Utilize a imagem imediatamente subsequente para estimar a pose relativa de cada imagem da sequência.
    :param imgs: lista de imagens de escala de cinza
    :param mtx: matriz intrínseca da câmera, a imagem já está des-distorcida
    :param velocidades: vetor de velocidades (m/s)
    :param tempos: vetor de tempos (s)
    Usa a função pegar_pontos_fluxo_optico que recebe duas imagens e retorna duas matrizes de pontos2d
    Retorna a trajetória percorrida, reconstruída tomando-se o primeiro quadro como a origem
    """
    lista_matrizes_rotacao = []
    lista_vetores_translacao = []
    for i in range(1, len(imgs)):
        rmat, tvec, _ = estima_rotacao_translacao(*pegar_pontos_fluxo_optico(imgs[i], imgs[i-1]), mtx)
        lista_matrizes_rotacao.append(rmat)
        lista_vetores_translacao.append(tvec)
    lista_vetores_deslocamento = [
        corrige_escala(vetor_translacao, velocidades[i], tempos[i+1] - tempos[i])
        for i, vetor_translacao in enumerate(lista_vetores_translacao)
    ]
    lista_rotacao_absoluta, lista_posicao_absoluta = reconstroi_trajetoria(lista_matrizes_rotacao, lista_vetores_deslocamento)
    return np.array(lista_rotacao_absoluta), np.array(lista_posicao_absoluta)

# %%
rotacoes, posicoes = odometria_mono_LK(imgs_esq[:70], mtx_esq, velocidades[:69], tempos[:70])
assert np.linalg.norm(rotacoes[0] - np.eye(3)) < 1e-6
assert np.linalg.norm(posicoes[0] - np.zeros(3)) < 1e-6
assert np.linalg.norm(rotacoes[-1] - np.array(
      [[-0.5063042 ,  0.04474437,  0.8611933 ],
       [ 0.03299499,  0.9989269 , -0.03250242],
       [-0.8617235 ,  0.01195895, -0.5072372 ]])) < 4e-2
assert np.linalg.norm(posicoes[-1] - np.array(
      [[38.33941  ],
       [ 0.7189929],
       [ 2.756405 ]])) < 1

# %%
plt.figure(figsize=(16, 6))
plt.plot(posicoes[:, 0, 0], posicoes[:, 2, 0], 'b-o', label='Odometria')
plt.plot(refs[:len(posicoes), 0, 3], refs[:len(posicoes), 2, 3], 'g-x', label='Referência')
plt.legend()
plt.xlabel('Distância em X (m)')
plt.ylabel('Distância em Y (m)')
plt.axis('equal')
plt.show()

# %% [markdown]
# ## Odometria Estéreo
#
# Agora não dependemos mais da informação de velocidade externa para estabelecer a realação de escala, uma vez que conhecemos as distâncias entre as câmeras (em metros), conseguimos determinar o nosso deslocamento (em metros), a partir da triangulação de pontos que sejam identificados

# %%
def pegar_pontos_iguais_quad(img_esq, img_esq_fut, img_dir, img_dir_fut):
    """
    Recebe quatro imagens e retorna uma lista com as coords. de pontos correspondentes nx2 por feature matching
    """
    imgs = [img_esq, img_esq_fut, img_dir, img_dir_fut]
    pts_des = [detector.detectAndCompute(img, None) for img in imgs] # Detecta e descreve bons pontos
    # Relaciona os pontos com a primeira imagem
    rels = [relacionador.knnMatch(des, pts_des[0][1], k=2) for pts, des in pts_des[1:]]
    rels_filtrados = [[r1 for r1, r2 in rel if r1.distance < 0.7 * r2.distance] for rel in rels]
    rels_t = [[r.trainIdx for r in rel] for rel in rels_filtrados]
    rels_q = [[r.queryIdx for r in rel] for rel in rels_filtrados]
    img0_idxs = [set(rt) for rt in rels_t]
    idxs_comuns = img0_idxs[0].intersection(*img0_idxs[1:])
    rels_intersect = [[rq[rt.index(i)] for i in idxs_comuns] for rt, rq in zip(rels_t, rels_q)]
    pts0 = np.array([pts_des[0][0][idx].pt for idx in idxs_comuns], dtype=np.float32)
    pts = [np.array([pts[idx].pt for idx in rels_intersect[i]], dtype=np.float32)
            for i, (pts , des) in enumerate(pts_des[1:])]
    return [pts0] + pts

def pegar_pontos_fluxo_optico_quad(img_esq, img_esq_fut, img_dir, img_dir_fut):
    """
    Recebe quatro imagens e retorna uma lista com as coords. de pontos correspondentes nx2 por Lukas-Kanade
    """
    p0 = cv2.goodFeaturesToTrack(img_esq, maxCorners=3200, qualityLevel=0.012, minDistance=8, blockSize=5)
    p1, status1, err = cv2.calcOpticalFlowPyrLK(img_esq, img_esq_fut, p0, None, winSize=(15, 15))
    p2, status2, err = cv2.calcOpticalFlowPyrLK(img_esq, img_dir, p0, None, winSize=(15, 15))
    p3, status3, err = cv2.calcOpticalFlowPyrLK(img_dir, img_dir_fut, p2, None, winSize=(15, 15))
    # Verifica se o vínculo estéreo está satisfeito (linhas epipolares horizontais)
    stereo1 = (np.abs(p0 - p2).reshape(-1, 2)[:, 1] < 1.2) & ((p0 - p2).reshape(-1, 2)[:, 0] > 0)
    stereo2 = (np.abs(p1 - p3).reshape(-1, 2)[:, 1] < 1.2) & ((p1 - p3).reshape(-1, 2)[:, 0] > 0)
    valid = ((status1 & status2 & status3).ravel() & stereo1 & stereo2).astype(np.bool8)
    return [p.reshape(-1, 2)[valid] for p in [p0, p1, p2, p3]]

# %% [markdown]
# Observe como fica o fluxo óptico de quadros de um mesmo instante entre câmeras retificadas

# %%
p1, p2, p3, p4 = pegar_pontos_fluxo_optico_quad(imgs_esq[40], imgs_esq[41], imgs_dir[40], imgs_dir[41])
img = np.repeat(imgs_esq[40][:, :, None], 3, axis=-1)
for pfut, p in zip(p3, p1): # Desenha uma linha ligando os pares de pontos
    cv2.line(img, np.int32(np.round(p)), np.int32(np.round(pfut)), (250, 250, 0))
print(len(p1))
PIL.Image.fromarray(img)
# Out:
# 1277
# <PIL.Image.Image image mode=RGB size=1226x370 at 0x7FC490C72550>

# %%
img = np.repeat(imgs_dir[40][:, :, None], 3, axis=-1)
for pfut, p in zip(p4, p3): # Desenha uma linha ligando os pares de pontos
    cv2.line(img, np.int32(np.round(p)), np.int32(np.round(pfut)), (250, 250, 0))
PIL.Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1226x370 at 0x7FC490C8DD30>

# %% [markdown]
# Uma das formas mais simples de agregar dados de múltiplas câmeras é fazer a média das rotações e dos deslocamentos que cada uma percebe. O ideal seria realizar a otimização conjunta de ambas as câmeras, mas como o OpenCV não tem uma função que faça um Bundle Adjustment, vamos quebrar em várias etapas e juntar os resultados como a média das câmreras.
#
# Mas primeiro é necessário corrigir os deslocamentos, uma vez que, a translação que a câmera da direita percebe (fora do "CG") é diferente translação que a câmera da esquerda percebe (que está no CG). Vamos levar todos esses deslocamentos para o CG, a fim de padronizar.
#
# Implemente a função abaixo que realiza essa correção. (1 ponto)

# %%
def compensa_cg(tvec, rotm, dist_cg):
    """
    Compensa a diferença de translação que a câmera da direita tem com relação à câmera da esquerda que está na
    origem ("CG") do carro
    :param tvec: Vetor de translação 3x1 do movimento observada pela câmera da direita
    :param rotm: Matriz de rotação 3x3 do movimento (observada por ambas as câmeras, 
                                    a rotação é a mesma para qualquer ponto no corpo)
    :dist_cg: Vetor de translação do CG (cam esquerda) até a câmera da direita
    """
    tvec_compensado_cg = tvec + (np.eye(3) - np.linalg.inv(rotm))@dist_cg
    return tvec_compensado_cg

# %%
assert np.linalg.norm(np.zeros((3,1)) - 
    compensa_cg(np.array([[-1], [0], [-1]]), R.from_euler('XYZ',[0,-np.pi/2,0]).as_matrix(), 
                np.array([[1],[0],[0]]))
                     ) < 1e-6
assert np.linalg.norm(np.array([[1-np.sqrt(2)/2],[0],[np.sqrt(2)/2]]) - 
    compensa_cg(np.array([[0], [0], [0]]), R.from_euler('XYZ',[0,-np.pi/4,0]).as_matrix(), 
                np.array([[1],[0],[0]]))
                     ) < 1e-6

# %% [markdown]
# Essas otimizações seriam melhores se fossem feitas em conjunto para o caso estéreo, mas como o OpenCV não tem um Bundle Adjustment, iniciamos estimando a rotação e translação monocular (para cada câmera em separado)

# %%
r1, t1, m1 = estima_rotacao_translacao(p2, p1, mtx_esq)
r2, t2, m2 = estima_rotacao_translacao(p4, p3, mtx_dir)
inliers = (m1 & m2).ravel().astype(np.bool8)
if np.sum(inliers) < 10: # Deixar tudo na mão do RANSAC do PnP
    inliers = np.ones((len(m1),), dtype=np.bool8)
media_rots = R.from_matrix([r1, r2]).mean().as_matrix()

# %% [markdown]
# Com base na triangulação dos pontos que tenham sido corretamente identificado nas 4 imagens, vamos uma triangulação para os pontos no passado e outra para os pontos do futuro. Daí já poderíamos identificar o deslocamento e a rotação entre essas nuvens de pontos, mas seria bom usar um RANSAC pois podem ter outliers.

# %%
pts4d = cv2.triangulatePoints(proj_esq, proj_dir, p1[inliers].T, p3[inliers].T)
pts3d = pts4d[:3, :] / pts4d[3:, :]
pts4d_fut = cv2.triangulatePoints(proj_esq, proj_dir, p2[inliers].T, p4[inliers].T)
pts3d_fut = pts4d_fut[:3, :] / pts4d_fut[3:, :]

# %% [markdown]
# Como já tem um RANSAC implementado no PnP, fica mais fácil usá-lo aqui. Assim, podemos aplicar o PnP de várias formas, com a geometria triangulada no passado ou no futuro, na câmera direita ou esquerda. Lembrando que se aplicar no passado/futuro será a transformação inversa obtida (ao invés de caminhar para frente estará caminhando para trás).

# %%
ok_esq, rvec_esq, tvec_esq, inliers_esq = cv2.solvePnPRansac(pts3d_fut.T, p1[inliers], mtx_esq, None)
ok_esq_i, rvec_esq_i, tvec_esq_i, inliers_esq_i = cv2.solvePnPRansac(pts3d.T, p2[inliers], mtx_esq, None)
ok_dir, rvec_dir, tvec_dir, inliers_dir = cv2.solvePnPRansac(pts3d_fut.T, p3[inliers], mtx_dir, None)
ok_dir_i, rvec_dir_i, tvec_dir_i, inliers_dir_i = cv2.solvePnPRansac(pts3d.T, p4[inliers], mtx_dir, None)

# %% [markdown]
# Daqui já podemos usar o resultado do PnP dos pontos triangulados para fazer saber a rotação e translação (já é o resultado do PnP, só com cuidado das transformações inversas `_i` e da correção do CG para a câmera direita.
#
# O exemplo abaixo realiza a odometria apenas com o PnP de uma câmera (esquerda) e triangulação dos pontos futuros.

# %%
inter = []
for i in range(70):
    p1, p2, p3, p4 = pegar_pontos_fluxo_optico_quad(imgs_esq[i], imgs_esq[i+1], imgs_dir[i], imgs_dir[i+1])
    r1, t1, m1 = estima_rotacao_translacao(p2, p1, mtx_esq)
    r2, t2, m2 = estima_rotacao_translacao(p4, p3, mtx_dir)
    inliers = (m1 & m2).ravel().astype(np.bool8)
    if np.sum(inliers) < 10: # Com poucos inliers o PnP quebra, colocar tudo e deixar o RANSAC
        inliers = np.ones((len(m1),), dtype=np.bool8)
    inter.append((p1, p2, p3, p4, r1, t1, r2, t2, inliers))

# %%
rot_rel, t_rel = [], []
for p1, p2, p3, p4, r1, t1, r2, t2, inliers in inter:
    pts4d_fut = cv2.triangulatePoints(proj_esq, proj_dir, p2[inliers].T, p4[inliers].T)
    pts3d_fut = pts4d_fut[:3, :] / pts4d_fut[3:, :]
    ok_esq, rvec_esq, tvec_esq, inliers_esq = cv2.solvePnPRansac(pts3d_fut.T, p1[inliers], mtx_esq, None)
    rot_rel.append(R.from_rotvec(rvec_esq.ravel()).as_matrix())
    t_rel.append(tvec_esq)
rs, ts = reconstroi_trajetoria(rot_rel, t_rel)
ts = np.array(ts)

plt.figure(figsize=(16, 6))
plt.plot(ts[:, 0, 0], ts[:, 2, 0], 'b-o', label='Odometria')
plt.plot(refs[:len(ts), 0, 3], refs[:len(ts), 2, 3], 'g-x', label='Referência')
plt.legend()
plt.xlabel('Distância em X (m)')
plt.ylabel('Distância em Y (m)')
plt.axis('equal')
plt.show()

# %% [markdown]
# Sinta-se à vontade para explorar e modificar o código, inclusive aumentando a quantidade de imagens a serem carregadas, são 700 frames no total.
#
# Por exemplo no código abaixo já temos a média, das rotações encontradas pela matriz essencial e das translações encontradas pelo PnP:

# %%
rot_rel, t_rel = [], []
for p1, p2, p3, p4, r1, t1, r2, t2, inliers in inter:
    pts4d = cv2.triangulatePoints(proj_esq, proj_dir, p1[inliers].T, p3[inliers].T)
    pts3d = pts4d[:3, :] / pts4d[3:, :]
    pts4d_fut = cv2.triangulatePoints(proj_esq, proj_dir, p2[inliers].T, p4[inliers].T)
    pts3d_fut = pts4d_fut[:3, :] / pts4d_fut[3:, :]
    ok_esq, rvec_esq, tvec_esq, inliers_esq = cv2.solvePnPRansac(pts3d_fut.T, p1[inliers], mtx_esq, None)
    ok_esq_i, rvec_esq_i, tvec_esq_i, inliers_esq_i = cv2.solvePnPRansac(pts3d.T, p2[inliers], mtx_esq, None)
    ok_dir, rvec_dir, tvec_dir, inliers_dir = cv2.solvePnPRansac(pts3d_fut.T, p3[inliers], mtx_dir, None)
    ok_dir_i, rvec_dir_i, tvec_dir_i, inliers_dir_i = cv2.solvePnPRansac(pts3d.T, p4[inliers], mtx_dir, None)
    rot_rel.append(R.from_matrix([r1, r2]).mean().as_matrix())
    t_rel.append((tvec_esq+compensa_cg(tvec_dir, rot_rel[-1], -t_dir)-t_dir)/2)
rs, ts = reconstroi_trajetoria(rot_rel, t_rel)
ts = np.array(ts)

plt.figure(figsize=(16, 6))
plt.plot(ts[:, 0, 0], ts[:, 2, 0], 'b-o', label='Odometria')
plt.plot(refs[:len(ts), 0, 3], refs[:len(ts), 2, 3], 'g-x', label='Referência')
plt.legend()
plt.xlabel('Distância em X (m)')
plt.ylabel('Distância em Y (m)')
plt.axis('equal')
plt.show()
